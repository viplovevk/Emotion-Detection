# %%
pip install deepface
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#
# ...
#   Created wheel for gdown: filename=gdown-4.2.0-py3-none-any.whl size=14262 sha256=9fe7639b5e8ef78d9398f661645564b41644ee91e4b5bad1a49097475d2422d1
#   Stored in directory: c:\users\viplo\appdata\local\pip\cache\wheels\2b\3c\51\52c46deda5cd1d59c6ce3d441ea5f3d155495dc294c4535a25
# Successfully built gdown
# ...

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
# Out:
# Directory  C:\Users\viplo /.deepface created
# Directory  C:\Users\viplo /.deepface/weights created

# %%
image=cv2.imread('D:\python image\download.jfif')
plt.imshow(image[:,:,::-1])
plt.show()

# %%
result = DeepFace.analyze(image, actions =['emotion'])

# %%
print(result)
# Out:
# {'emotion': {'angry': 5.548894639489445e-15, 'disgust': 3.665977494123681e-35, 'fear': 1.3300342773445988e-22, 'happy': 99.99996423721313, 'sad': 2.1518623209067244e-14, 'surprise': 7.913067343577346e-13, 'neutral': 4.100886883406929e-05}, 'dominant_emotion': 'happy', 'region': {'x': 164, 'y': 21, 'w': 89, 'h': 89}}

# %%
image1=cv2.imread('D:\python image\kohli.jpeg')
plt.imshow(image1[:,:,::-1])
plt.show()

# %%
result1 = DeepFace.analyze(image1, actions =['emotion'])

# %%
print(result1)
# Out:
# {'emotion': {'angry': 51.20975375175476, 'disgust': 3.120705915904409e-08, 'fear': 48.759832978248596, 'happy': 0.00035593966458691284, 'sad': 0.03005513281095773, 'surprise': 5.8551830051101206e-09, 'neutral': 4.532962980668964e-10}, 'dominant_emotion': 'angry', 'region': {'x': 191, 'y': 48, 'w': 145, 'h': 145}}

# %%
image3=cv2.imread('D:\python image\kirti.jpg')
plt.imshow(image3[:,:,::-1])
plt.show()

# %%
result3 = DeepFace.analyze(image3, actions =['emotion'])

# %%
print(result3)
# Out:
# {'emotion': {'angry': 0.4753127046115818, 'disgust': 4.344655596679649e-05, 'fear': 0.45778777384983144, 'happy': 6.446267303601939, 'sad': 83.92885231547668, 'surprise': 0.0002451673854623457, 'neutral': 8.69149170467208}, 'dominant_emotion': 'sad', 'region': {'x': 129, 'y': 53, 'w': 258, 'h': 258}}
